# %% [markdown]
# ## JSON dataframe check
#
# Simple toy for checking all the columns of a new JSON

# %%
import pandas as pd
import json
import numpy as np
import csv

from tqdm import tqdm
import inflect
import copy

recipes_filename_parsed = "../data/full_format_recipes_parsed.json"

# %%
df = pd.read_json(recipes_filename_parsed)
df.head()
# Out:
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
# 2  [In a large heavy saucepan cook diced fennel a...   7.0
# 3  [Heat oil in heavy large skillet over medium-h...   NaN
# 4  [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
#
#                  date                                         categories  \
# 0 2006-09-01 04:00:00  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1 2004-08-20 04:00:00  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2 2004-08-20 04:00:00  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3 2009-03-27 04:00:00  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4 2004-08-20 04:00:00  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
#
#    calories                                               desc  protein  \
# 0     426.0                                               None     30.0
# ...

# %%
import random
i = random.randint(0, len(df))

print('INGREDIENTS')
print(df['ingredients'][i], '\n')
print(df['ingredients_individually'][i], '\n')
print(df['ingredients_preformatted'][i], '\n')
print(df['ingredients_to_cnn'][i], '\n \n')

print('CATEGORIES')
print(df['categories'][i], '\n')
print(df['categories_preformatted'][i], '\n')
# Out:
# INGREDIENTS
# ['2 large eggplants', 'Juice of 1 lemon', '1 tablespoon ground cumin', '1 garlic clove, chopped', '1 1/2 tablespoons olive oil', 'Salt and pepper, to taste', '1 tablespoon finely chopped parsley', '1 cup tehina , if desired']
#
# ['eggplants', 'lemon', 'cumin', 'garlic', 'olive oil', 'pepper', 'parsley']
#
# ['oil', 'parsley', 'cumin', 'garlic', 'lemon', 'pepper', 'eggplant']
#
# ['oil', 'garlic', 'lemon']
#
#
# CATEGORIES
# ['Condiment/Spread', 'Vegetable', 'Eggplant', 'Fall', 'Healthy']
#
# []
